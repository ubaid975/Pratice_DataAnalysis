# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
list1 = [1,2,3,4]
list2 = [1,5,6,3,7]

list3 = list1 +list2
print(sorted(list3))
# Out:
# [1, 1, 2, 3, 3, 4, 5, 6, 7]

# %%
data=pd.read_excel('SaleData (1)1.xlsx')

# %%
data
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
data.isnull().sum()
# Out:
# OrderDate     0
# Region        0
# Manager       0
# SalesMan      0
# Item          0
# Units         0
# Unit_price    0
# Sale_amt      0
# dtype: int64

# %%
data['Item'].fillna(data.Item.mode()[0],inplace=True)

# %%
data.Item.head()
# Out:
# 0      Television
# 1    Home Theater
# 2      Television
# 3      Cell Phone
# 4      Television
# Name: Item, dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
 plt.plot(data.Units,data.Sale_amt,color="r",marker='o',markersize=13)

# %%
data.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %%
plt.hist([data.Units,data.Unit_price,data.Sale_amt])
# Out:
# (array([[45.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [45.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [17.,  7.,  5.,  6.,  1.,  3.,  1.,  2.,  0.,  3.]]),
#  array([2.000000e+00, 1.138280e+04, 2.276360e+04, 3.414440e+04,
#         4.552520e+04, 5.690600e+04, 6.828680e+04, 7.966760e+04,
#         9.104840e+04, 1.024292e+05, 1.138100e+05]),
#  <a list of 3 BarContainer objects>)

# %%
plt.bar(data.Unit_price,data.Units,width=1)
# Out:
# <BarContainer object of 45 artists>

# %%
data.head(2)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0

# %%
for i in range(10):
    print('marya')
# Out:
# marya
# marya
# marya
# marya
# marya
# marya
# marya
# marya
# marya
# marya

# %%
with open('marya','w'):
    compile

# %%
with open('marya','r'):
    compile

# %%
import os

# %%
ubaid=os.device_encoding(999)

# %%
ubaid

# %%
print(ubaid)
# Out:
# None

# %%
os.open('')
