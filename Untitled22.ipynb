# %%
import pandas as pd

# %%
data=pd.read_csv('marketing_data.csv',header=[0])

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
data.Income
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name: Income, Length: 2240, dtype: object

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data.Income.fillna(data.Income.median())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:785, in nanmedian(values, axis, skipna, mask)
#     784 try:
# --> 785     values = values.astype("f8")
#     786 except ValueError as err:
#     787     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: '$84,835.00 '
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data.Income.fillna(data.Income.median())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6235, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6227 @doc(make_doc("median", ndim=1))
#    6228 def median(
#    6229     self,
#    (...)
#    6233     **kwargs,
#    6234 ):
# ...

# %%
type(data.Income)
# Out:
# pandas.core.series.Series

# %%
data.Income.fillna(data.Income.mode()[0],inplace=True)

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
import numpy as np

# %%
np.shape(data)
# Out:
# (2240, 28)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2240 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
data['Income']
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name: Income, Length: 2240, dtype: object

# %%
data.head(10)
# Out:
#       ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0   1826        1970  Graduation       Divorced  $84,835.00         0
# 1      1        1961  Graduation         Single  $57,091.00         0
# 2  10476        1958  Graduation        Married  $67,267.00         0
# 3   1386        1967  Graduation       Together  $32,474.00         1
# 4   5371        1989  Graduation         Single  $21,474.00         1
# 5   7348        1958         PhD         Single  $71,691.00         0
# 6   4073        1954    2n Cycle        Married  $63,564.00         0
# 7   1991        1967  Graduation       Together  $44,931.00         0
# 8   4047        1954         PhD        Married  $65,324.00         0
# 9   9477        1954         PhD        Married  $65,324.00         0
#
#    Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0         0     6/16/14        0       189  ...                  6
# ...

# %%
data.tail(20)
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 2220   5871        1979      Master       Together  $24,401.00         0
# 2221   3846        1974  Graduation        Married  $42,557.00         0
# 2222  10001        1985    2n Cycle       Together   $7,500.00         1
# 2223   2831        1976  Graduation       Together  $78,416.00         0
# 2224    868        1966  Graduation        Married  $44,794.00         0
# 2225   7212        1966  Graduation        Married  $44,794.00         0
# 2226   1743        1974  Graduation         Single  $69,719.00         0
# 2227   2415        1962  Graduation       Together  $62,568.00         0
# 2228   7947        1969  Graduation        Married  $42,231.00         1
# 2229   2106        1974    2n Cycle        Married  $20,130.00         0
# 2230   3363        1974    2n Cycle        Married  $20,130.00         0
# 2231   8595        1973  Graduation          Widow  $42,429.00         0
# ...

# %%
data.Income
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name: Income, Length: 2240, dtype: object

# %%
data.Income.astype('str')
# Out:
# 0       $84,835.00
# 1       $57,091.00
# 2       $67,267.00
# 3       $32,474.00
# 4       $21,474.00
#            ...
# 2235    $66,476.00
# 2236    $31,056.00
# 2237    $46,310.00
# 2238    $65,819.00
# 2239    $94,871.00
# Name: Income, Length: 2240, dtype: object

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2235    False
# 2236    False
# 2237    False
# 2238    False
# 2239    False
# Length: 2240, dtype: bool

# %%
data[data.isnull()]
# Out:
#       ID  Year_Birth Education Marital_Status Income  Kidhome  Teenhome  \
# 0    NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 1    NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 2    NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 3    NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 4    NaN         NaN       NaN            NaN    NaN      NaN       NaN
# ...   ..         ...       ...            ...    ...      ...       ...
# 2235 NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 2236 NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 2237 NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 2238 NaN         NaN       NaN            NaN    NaN      NaN       NaN
# 2239 NaN         NaN       NaN            NaN    NaN      NaN       NaN
#
#      Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data[data.isnull]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 data[data.isnull]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3856, in DataFrame.__getitem__(self, key)
#    3854 check_dict_or_set_indexers(key)
#    3855 key = lib.item_from_zerodim(key)
# -> 3856 key = com.apply_if_callable(key, self)
#    3858 if is_hashable(key) and not is_iterator(key):
#    3859     # is_iterator to exclude generator e.g. test_getitem_listlike
#    3860     # shortcut if the key is in columns
#    3861     is_mi = isinstance(self.columns, MultiIndex)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:379, in apply_if_callable(maybe_callable, obj, **kwargs)
#     368 """
#     369 Evaluate possibly callable input using obj and kwargs if it is callable,
#     370 otherwise return as it is.
#    (...)
#     376 **kwargs
#     377 """
# ...

# %%
data.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data[data.Income==data.Income.max()]
# Out:
#        ID  Year_Birth Education Marital_Status      Income  Kidhome  Teenhome  \
# 518  7451        1960    Master         Single  $99,777.00        0         0
#
#     Dt_Customer  Recency  MntWines  ...  NumStorePurchases  NumWebVisitsMonth  \
# 518     2/17/14       23      1000  ...                  9                  1
#
#      AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# 518             0             1             0             0             0
#
#      Response  Complain  Country
# 518         0         0       SP
#
# [1 rows x 28 columns]

# %%
data.iloc[518,4]="$99,777.00"

# %%
data.Income.max()
# Out:
# '$99,777.00'

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
a=data[data['Education']=="Graduation"][['Country','Income']]

# %%
data.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
a
# Out:
#      Country       Income
# 0         SP  $84,835.00
# 1         CA  $57,091.00
# 2         US  $67,267.00
# 3        AUS  $32,474.00
# 4         SP  $21,474.00
# ...      ...          ...
# 2231     AUS  $42,429.00
# 2232      SP  $42,429.00
# 2234      US  $78,901.00
# 2237      SP  $46,310.00
# 2238     IND  $65,819.00
#
# [1127 rows x 2 columns]

# %%
a.tail(30)
# Out:
#      Country       Income
# 2184      SP  $55,761.00
# 2185      SA  $78,331.00
# 2186      US  $37,971.00
# 2187      SP  $30,368.00
# 2190      SP  $69,932.00
# 2192      CA  $93,404.00
# 2193      US  $38,680.00
# 2194      SP  $24,570.00
# 2197      SA  $64,961.00
# 2199      SA  $45,989.00
# 2206      SA  $73,455.00
# 2207      SP  $84,906.00
# 2208     GER  $84,906.00
# 2210      SP  $44,529.00
# 2214      SP  $41,154.00
# 2215      SP  $64,590.00
# 2218      US  $83,273.00
# 2219      CA  $81,702.00
# 2221      SP  $42,557.00
# 2223      SP  $78,416.00
# 2224      SA  $44,794.00
# 2225     AUS  $44,794.00
# 2226      SP  $69,719.00
# 2227      SP  $62,568.00
# 2228      SP  $42,231.00
# 2231     AUS  $42,429.00
# 2232      SP  $42,429.00
# 2234      US  $78,901.00
# 2237      SP  $46,310.00
# 2238     IND  $65,819.00

# %%
data.Income.argmax()
# Out:
# 518

# %%
data.loc[518,'Income']
# Out:
# '$99,777.00'

# %%
data
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
data[data.Dt_Customer<="9/1/12"]
# Out:
#          ID  Year_Birth   Education Marital_Status       Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
x=10

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 lamda
#
# NameError: name 'lamda' is not defined
