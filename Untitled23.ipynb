# %%
import pandas as pd

# %%
data1=pd.read_excel('test_data.xlsx',)
data2=pd.read_excel('test_data.xlsx',sheet_name=1)
data3=pd.read_excel('test_data.xlsx',sheet_name=2)

# %%
data1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
data2
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
data3
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4        Fatima        E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
data1.merge(data3)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0             1           Asad        Karachi         123   Jawed       A
# 1             4         Hassan         Lahore         567   Najam       G
# 2             6         Kashif      Hyderabad         234  Faisal       F
# 3             7           Sana         Lahore         567  Faisal       D
#
#    Sales  Amount
# 0    100   100000
# 1    129   125000
# 2    123   825000
# 3    231   652000

# %%
data1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
data1.sales_man_name=data1.sales_man_name.apply(lambda x : x.strip())

# %%
data1.merge(data3)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0             1           Asad        Karachi         123   Jawed       A
# 1             4         Hassan         Lahore         567   Najam       G
# 2             6         Kashif      Hyderabad         234  Faisal       F
# 3             7           Sana         Lahore         567  Faisal       D
#
#    Sales  Amount
# 0    100   100000
# 1    129   125000
# 2    123   825000
# 3    231   652000

# %%
data1.merge(data3,how='outer')
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0            1.0           Asad        Karachi       123.0   Jawed       A
# 1            2.0         Sumair         Lahore       123.0   Jawed     NaN
# 2            3.0         Farjad        Karachi       145.0   Najam     NaN
# 3            4.0         Hassan         Lahore       567.0   Najam       G
# 4            5.0          Nasir      Hyderabad       234.0   Jawed     NaN
# 5            6.0         Kashif      Hyderabad       234.0  Faisal       F
# 6            7.0           Sana         Lahore       567.0  Faisal       D
# 7            8.0         Fatima        Karachi       345.0   Najam     NaN
# 8            9.0       Abdullah        Karachi       123.0  Faisal     NaN
# 9            NaN        Hussain            NaN         NaN     NaN       B
# 10           NaN            Ali            NaN         NaN     NaN       C
# ...

# %%
data1.merge(data3)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0             1           Asad        Karachi         123   Jawed       A
# 1             4         Hassan         Lahore         567   Najam       G
# 2             6         Kashif      Hyderabad         234  Faisal       F
# 3             7           Sana         Lahore         567  Faisal       D
#
#    Sales  Amount
# 0    100   100000
# 1    129   125000
# 2    123   825000
# 3    231   652000

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# %%
data=pd.read_excel('test_data.xlsx')
data1=pd.read_excel('test_data.xlsx',sheet_name=1)
data2=pd.read_excel('test_data.xlsx',sheet_name=2)

# %%
data
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
data1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
data2
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4        Fatima        E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
data['sales_man_name']=data['sales_man_name'].apply(lambda x: x.strip())

# %%
data
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
pd.merge(data1,data3)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0            44           Asad         Lahore         567   Najam       A
# 1            55        Hussain      Hyderabad         234   Jawed       B
# 2            66            Ali      Hyderabad         234  Faisal       C
# 3            99            Ali        Karachi         123  Faisal       C
#
#    Sales  Amount
# 0    100   100000
# 1    300   450000
# 2    234   125000
# 3    234   125000

# %%
data3
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4        Fatima        E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
data1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
data
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
data[data["manager"]=='Jawed']
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 4             5          Nasir      Hyderabad         234   Jawed
